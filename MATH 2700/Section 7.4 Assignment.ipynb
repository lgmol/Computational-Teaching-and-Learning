# %% [markdown]
# # Section 7.4 Assignment

# %% [markdown]
# ## Counting Derangments

# %% [markdown]
# Recall from the course notes that the number of derangments of $[n]$ is given by
# $$
# d_n=\sum_{k=0}^n (-1)^k \binom{n}{k}(n-k)!
# $$
# Complete the definition of the function `d(n)` below so that it returns the number of derangements of $[n]$.

# %%
k=var('k')

def d(n):
    return # YOUR CODE HERE

# %% [markdown]
# Using a `for` loop, we can print the number of derangements of $[n]$ for all $n$ from $1$ to $10$.

# %%
for n in range(1,11):      # Note that range(1,11) indicates the range from 1 to 10.  (11 is where it halts.)
    print(n,d(n))

# %% [markdown]
# ## The Probability that a Random Permutation is a Derangement

# %% [markdown]
# **(a)** Suppose that Lucas is in a rush to hand back quizzes to $5$ students.  If he hands them back completely randomly, then what is the probability that no one gets their own quiz back?
#
# **Hint:** How many ways are there to hand the quizzes back?  Assume that they are all equally likely to occur.

# %%
# YOUR CODE HERE

# %% [markdown]
# **(b)** What if there are $n$ students instead of $5$?  Write a procedure `p(n)` that returns this probability for any input `n`.

# %%
# YOUR CODE HERE

# %% [markdown]
# **(c)** Print the probability $p(n)$ for all $n$ from $1$ to $10$.

# %%
# YOUR CODE HERE

# %% [markdown]
# **(d)** Run the code below to plot these probabilities for $n$ from $1$ to $10$.  What do you notice?

# %%
prob_list = [(n,p(n)) for n in range(1,11)]
list_plot(prob_list, size=20, color='blue', axes_labels=['$n$', 'Probability'])
