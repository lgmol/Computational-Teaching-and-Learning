# %% [markdown]
# # Minimum Weight Spanning Trees
#
# In this notebook, we will learn how to use the built-in function <code>min_spanning_tree</code> to run Kruskal's algorithm and Prim's algorithm.  Then we will write our own implementation of Kruskal's algorithm.

# %% [markdown]
# ## Weighted Graphs
#
# First, we learn how to construct and work with (edge)-weighted graphs in Sage.  First we define a graph and print its list of edges.

# %%
n=6
p=0.5
G = graphs.RandomGNP(n,p)
while not G.is_connected():
    G = graphs.RandomGNP(n,p)
G.show(save_pos=True)
G.edges()

# %% [markdown]
# Note that each edge is a 3-tuple.  The first two entries are its endpoints, and the third entry is set to <code>None</code> by default.  We can use this third entry to store the weight of the edge.
#
# We can access the three entries of an edge <code>e</code> with <code>e[0]</code>, <code>e[1]</code>, and <code>e[2]</code>.
#
# Let's add a weight to each edge in $G$.  We will let the weight of each edge <code>e</code> be the sum of the labels of its endpoints.

# %%
for e in G.edges():
    G.add_edge(e[0],e[1],e[0]+e[1])
G.edges()

# %% [markdown]
# Now we can print a drawing of the weighted graph $G$.

# %%
plt = G.graphplot(edge_labels=True)  # Creates a plot object in which the edge weights will be shown
plt.show()  # Displays the plot

# %% [markdown]
# ## The Built-in Function <code>min_spanning_tree</code>

# %% [markdown]
# Now that our graph $G$ is weighted, we can run the built-in function <code>min_spanning_tree</code> to find a minimum spanning tree of $G$.

# %%
weight=lambda e:e[2]  # Tells Sage that we want to treat the last coordinate of each edge as its weight
G.min_spanning_tree(weight_function=weight)  # Finds a minimum weight spanning tree in G

# %% [markdown]
# Note that <code>G.min_spanning_tree()</code> returns the list of edges of a minimum spanning tree of $G$.  We write a function below that returns a drawing of $G$ in which the edges of the minimum spanning tree are coloured red.

# %%
def color_special_edges_red(G,special_edges):
    edge_colors={}
    edge_colors['red']=special_edges
    plt=G.graphplot(edge_colors=edge_colors,edge_labels=True)
    plt.show()

# %% [markdown]
# Now we can see the minimum spanning tree!

# %%
spanning_tree=G.min_spanning_tree(weight_function=weight)
color_special_edges_red(G,spanning_tree)

# %% [markdown]
# One can pass several options to <code>min_spanning_tree</code> in order to run a specific algorithm (e.g., Kruskal's algorithm, Prim's algorithm starting at a specified vertex) to compute the minimum weight spanning tree.
# - The <code>algorithm</code> option can be set to 'Kruskal' to run Kruskal's algorithm, or 'Prim_Boost' to run Prim's algorithm.
# - The <code>starting_vertex</code> option is used to set the starting vertex for Prim's algorithm.
#
# See the <a href="https://doc.sagemath.org/html/en/reference/graphs/sage/graphs/generic_graph.html#sage.graphs.generic_graph.GenericGraph.min_spanning_tree">Sage Documentation</a> for the complete list of options.

# %%
spanning_tree=G.min_spanning_tree(weight_function=weight,algorithm='Kruskal')
color_special_edges_red(G,spanning_tree)

# %%
spanning_tree=G.min_spanning_tree(weight_function=weight,algorithm='Prim_Boost',starting_vertex=0)
color_special_edges_red(G,spanning_tree)

# %% [markdown]
# ## Our own implementation of Kruskal's algorithm

# %% [markdown]
# We will take as input a graph in which all edges contain a weight as their last coordinate.

# %%
def MinimumSpanningTree(G):

    if not G.is_connected():       # If G is not connected, then it will not have any spanning trees!
        print("The input graph is not connected.")
        return None

    E=list(G.edges())  # E is the list of all edges of G.
    E.sort(key=lambda e: e[2])  # Sorts the list of edges in nondecreasing order by weight.  Remember that e[2] is the weight of the edge e.

    S=Graph() # Initialize S as the empty graph.  We will add edges to S until it is a spanning tree.
    i=0       # Initialize i as 0.  We will use i as an index for running through the list of edges.

    n=G.order()  # Let n be the number of vertices of the input graph

    while S.size()<n-1:   # We want to continue adding edges until we have n-1 edges.  (Every connected graph with n vertices and n-1 edges is a tree.) 
        
        S.add_edge(E[i])  # Add the next edge in the sorted list.
        
        if not S.is_forest():     # Check to see if adding the edge E[i] created a cycle.
            S.delete_edge(E[i])   # If it did, then we don't want to add that edge!  So we remove it here.
            
        i+=1  # Move on to the next edge in the sorted list.
        
    return S.edges()  # We return the edge set of S.

# %%
S=MinimumSpanningTree(G)
print(S)
color_special_edges_red(G,S)

# %% [markdown]
# To find the weight of our minimum weight spanning tree, we simply need to sum the weights of all edges in the tree.

# %%
def WeightOfMinimumSpanningTree(G):

    S=MinimumSpanningTree(G)
    weight=sum(e[2] for e in S)

    return weight

# %%
WeightOfMinimumSpanningTree(G)
