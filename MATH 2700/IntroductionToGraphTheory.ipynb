# %% [markdown]
# ### Introduction to Graph Theory in Sage

# %% [markdown]
# Sage is an indispensable tool for the graph theorist.  In this notebook, we will learn how to use some of the built-in functions for graphs in Sage.

# %%
G = graphs.RandomGNP(8,0.5)  # A random graph on 8 vertices in which each edge is included with probability 0.5

# Feel free to change 8 to any positive integer you like, and 0.5 to any real number in (0,1).

G.show() # Display the graph G

# %% [markdown]
# What are each of the commands below doing? Try regenerating the random graph above and then re-running the commands below to confirm your guesses.

# %%
G.order()

# %%
G.size()

# %%
G.vertices()

# %%
G.edges()

# %%
G.is_connected()

# %%
G.is_eulerian()

# %%
G.eulerian_circuit()

# %% [markdown]
# ## Your Turn!
# Write code below to determine whether or not the graph $G$ is Hamiltonian, and to find a Hamiltonian cycle in $G$, if it exists.
#
# **Hint:** Search for "hamiltonian" in the [SageMath documentation](https://doc.sagemath.org/html/en/reference/graphs/sage/graphs/generic_graph.html).

# %%
# YOUR CODE HERE - Is G Hamiltonian?

# %%
# YOUR CODE HERE - If G is Hamiltonian, identify a Hamilton cycle

# %% [markdown]
# ## Common Graphs
#
# Do you want to know something about a specific graph?  There are several ways to define a specific graph in Sage.  First of all, there are many pre-defined families of graphs (paths, cycles, complete graphs, etc.).

# %%
P=graphs.PathGraph(4) # A path on 4 vertices
P.show()

# %%
C=graphs.CycleGraph(5) # A cycle on 5 vertices
C.show()

# %%
B=graphs.CompleteBipartiteGraph(3,4) # A complete bipartite graph with partite sets of orders 3 and 4
B.show()

# %%
S = graphs.StarGraph(5) # A star with 5 leaves (hence 6 vertices total!)
S.show()

# %% [markdown]
# ## Your Turn
#
# Define and display a star graph on 8 vertices.  Assign this graph to the variable `S8`.

# %%
# YOUR CODE HERE

# %% [markdown]
# Make sure that your star graph has 8 vertices, as desired!

# %% [markdown]
# Define and display a complete graph on 5 vertices.  If in doubt, search for "complete" in the [SageMath documentation](https://doc.sagemath.org/html/en/reference/graphs/sage/graphs/generic_graph.html).

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Custom Graphs
#
# You can also define a graph using the `Graph` command.  You must provide a list of edges.

# %%
G = Graph() # Creates the null graph (with no vertices and no edges) and assigns it to the variable G
G.add_vertices([0,1,2,3,4]) # Add the vertices in the list [1,2,3,4,5] to G
G.add_edges([(0,1),(1,2),(2,3),(3,1)])
G.show()

# %% [markdown]
# Once a graph is constructed, you can add more vertices (or edges) whenever you like. Note that add_vertex and add_edge take as input a single vertex or edge, respectively, while add_vertices and add_edges take as input a list of vertices or edges, respectively.

# %%
G.add_vertex(5)
G.add_edges([(3,4),(2,5)])
G.show()

# %% [markdown]
# ## Your turn
#
# Construct a graph that is Eulerian but not Hamiltonian.  Assign it to the variable `E`.

# %%
# YOUR CODE HERE

# %% [markdown]
# Check that `E` is Eulerian.

# %%
# YOUR CODE HERE

# %% [markdown]
# Check that `E` is not Hamiltonian.

# %%
# YOUR CODE HERE
